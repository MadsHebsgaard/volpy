# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

import pandas as pd
import wrds
import importlib
import volpy_func_lib as vp

import wrds_lib as wl
import wrds_lib2 as wl2
import load_clean_lib

importlib.reload(wl)
importlib.reload(wl2)
importlib.reload(vp)

db = wrds.Connection(wrds_username="axelledue")
# Out:
# Loading library list...
# Done

# %%
db.close
# Out:
# <bound method Connection.close of <wrds.sql.Connection object at 0x0000027F786E6190>>

# %%
vp.ALL_tickers
# Out:
# ['ABT',
#  'C',
#  'MSFT',
#  'BA',
#  'EZA',
#  'AMZN',
#  'S',
#  'BITO',
#  'LLY',
#  'DELL',
#  'EMC',
#  'IBM',
#  'MCD',
#  'RAL',
#  'DVN',
#  'HAL',
#  'INTC',
#  'GOOG',
#  'WYE',
#  'OEF',
#  'TXN',
#  'MS',
#  'TMUS',
#  'TLT',
#  'EBAY',
#  'CMCSK',
#  'MO',
#  'EWJ',
#  'EWZ',
#  'HYG',
#  'AEP',
#  'MMM',
#  'DIA',
#  'CL',
#  'PEP',
#  'DIS',
#  'ABBV',
#  'OEX',
#  'UBAN',
#  'TWX',
#  'F',
#  'PYPL',
#  'UIS',
#  'EEM',
#  'SLV',
#  'USB',
#  'CLB',
#  'JNJ',
#  'MDT',
#  'NYX',
#  'WMB',
#  'HPQ',
#  'GBLX',
#  'ROK',
#  'AA',
#  'HNZ',
#  'DUK',
#  'IWM',
#  'CMCSA',
#  'INDA',
#  'XRX',
#  'LOW',
#  'ONE',
#  'PG',
#  'NSC',
#  'EMB',
#  'PARA',
#  'UPS',
#  'TIP',
#  'KHC',
#  'SBUX',
#  'JCI',
#  'RSH',
#  'BK',
#  'CVS',
#  'MET',
#  'AVGO',
#  'SLB',
#  'WBA',
#  'VNQ',
#  'AVP',
#  'ALL',
#  'COST',
#  'LMT',
#  'USO',
#  'EMR',
#  'RTX',
#  'HIG',
#  'COP',
#  'RF',
#  'TOY',
#  'SCHW',
#  'NKE',
#  'OXY',
#  'HD',
#  'CAT',
#  'LQD',
#  'DAL',
#  'OMX',
#  'AAPL',
#  'GD',
#  'GOOGL',
#  'IP',
#  'FXY',
#  'CI',
#  'DE',
#  'QCOM',
#  'CEW',
#  'DOW',
#  'TGT',
#  'VGK',
#  'EWW',
#  'HCA',
#  'VZ',
#  'RTN',
#  'CVX',
#  'FXI',
#  'NFLX',
#  'CSC',
#  'BRK',
#  'GILD',
#  'MDLZ',
#  'UNP',
#  'AMGN',
#  'EWU',
#  'JPM',
#  'IAU',
#  'UNG',
#  'BDK',
#  'COV',
#  'GM',
#  'BAX',
#  'NSM',
#  'HET',
#  'TMO',
#  'FCX',
#  'AMT',
#  'UUP',
#  'CGP',
#  'CSCO',
#  'HON',
#  'WY',
#  'BAC',
#  'SPX',
#  'DD',
#  'MA',
#  'MAY',
#  'BKNG',
#  'CRM',
#  'V',
#  'ENE',
#  'APC',
#  'MRK',
#  'KO',
#  'NT',
#  'T',
#  'COF',
#  'SPG',
#  'BNI',
#  'EP',
#  'UVXY',
#  'G',
#  'AES',
#  'BMY',
#  'NOV',
#  'ORCL',
#  'EWY',
#  'GTX',
#  'BHI',
#  'HSH',
#  'META',
#  'MON',
#  'PM',
#  'CHTR',
#  'TSLA',
#  'EWC',
#  'APA',
#  'ADBE',
#  'EXC',
#  'XOM',
#  'MER',
#  'WB',
#  'BUD',
#  'BIIB',
#  'AGN',
#  'DHR',
#  'NVDA',
#  'GS',
#  'CELG',
#  'SO',
#  'QQQ',
#  'LEH',
#  'UNH',
#  'PFE',
#  'AMD',
#  'SGP',
#  'NEE',
#  'FXE',
#  'AXP',
#  'FDX',
#  'KMI',
#  'WMT',
#  'ACN',
#  'GE',
#  'EWA',
#  'PNU',
#  'WFC',
#  'ETR',
#  'NXTL',
#  'AIG',
#  'LIN',
#  'CPB',
#  'ATI',
#  'SHY']

# %% [markdown]
# # create option, forward and return csv files

# %%
importlib.reload(wl2)

wl2.fetch_wrds_data_per_ticker(db, 
                               tickers = ['APT', 'S', 'EBAY', 'GOOG'] , #['AAPL','MSFT','TSLA','AMZN','NVDA']
                               chunk_size=4000000/2)
# Out:
# Skipping already existing tickers: APT, S, EBAY
# Importing option data: 100%|██████████| 1/1 [03:31<00:00, 211.26s/ticker, ticker=GOOG]
# Importing forward prices: 100%|██████████| 1/1 [00:01<00:00,  1.54s/ticker, ticker=GOOG]
# Importing stock returns: 100%|██████████| 1/1 [00:00<00:00,  2.33ticker/s, ticker=GOOG]
# Importing yield curve data into: C:\Users\axell\Desktop\CBS\data\OptionMetrics\Tickers\ZC yield curve.csv
# Data collected and saved: 72597 rows.

# %%
importlib.reload(wl)

wl.fetch_wrds_data(
    db = db,
    folder_name="OEX2",
    begdate="2013-01-01", 
    enddate="2024-12-31", #2024-12-31 2003-02-28
    save_per="Y", #None "Y" "M"
    tickers = ["OEX", "OEF","AA", "AAPL", "ABBV", "ABT", "ACN", "ADBE", 
               "AEP", "AES", "AGN", "AIG", "ALL", "AMD", "AMGN", "AMT", 
               "AMZN", "APA", "APC", "ATI", "AVGO", "AVP", "AXP", "BA", 
               "BAC", "BAX", "BDK", "BHI", "BIIB", "BK", "BKNG", "BMY", 
               "BNI", "BRK", "BUD", "C", "CAT", "CELG", "CGP", "CHTR", "CI", 
               "CL", "CLB", "CMCSA", "CMCSK", "COF", "COP", "COST", "COV", 
               "CPB", "CRM", "CSC", "CSCO", "CVS", "CVX", "DAL", "DD", "DE", 
               "DELL", "DHR", "DIS", "DOW", "DUK", "DVN", "EBAY", "EMC", "EMR", 
               "ENE", "EP", "ETR", "EXC", "F", "FCX", "FDX", "G", "GBLX", "GD", 
               "GE", "GILD", "GM", "GOOG", "GOOGL", "GS", "GTX", "HAL", "HCA", 
               "HD", "HET", "HIG", "HNZ", "HON", "HPQ", "HSH", "IBM", "INTC", 
               "IP", "JCI", "JNJ", "JPM", "KHC", "KMI", "KO", "LEH", "LIN", 
               "LLY", "LMT", "LOW", "MA", "MAY", "MCD", "MDLZ", "MDT", "MER", 
               "MET", "META", "MMM", "MO", "MON", "MRK", "MS", "MSFT", "NEE", 
               "NFLX", "NKE", "NOV", "NSC", "NSM", "NT", "NVDA", "NXTL", "NYX", 
               "OMX", "ONE", "ORCL", "OXY", "PARA", "PEP", "PFE", "PG", "PM", 
               "PNU", "PYPL", "QCOM", "RAL", "RF", "ROK", "RSH", "RTN", "RTX", 
               "S", "SBUX", "SCHW", "SGP", "SLB", "SO", "SPG", "T", "TGT", "TMO", 
               "TMUS", "TOY", "TSLA", "TWX", "TXN", "UBAN", "UIS", "UNH", "UNP", 
               "UPS", "USB", "V", "VZ", "WB", "WBA", "WFC", "WMB", "WMT", "WY", 
               "WYE", "XOM", "XRX"],
    progress=True,
    chunk_size=4000000/2,
    return_df=False
)
# Out:
# Importing O-data split per 'Y' into folder: C:\Users\axell\Desktop\CBS\data\OptionMetrics\OEX2
# Collecting data: 100%|██████████| 11/11 [2:02:48<00:00, 669.91s/years]
# Importing F-data into: C:\Users\axell\Desktop\CBS\data\OptionMetrics\OEX2\forward price.csv
# Collecting data: 100%|██████████| 11/11 [01:06<00:00,  6.06s/years]
# Data collected and saved: 4224523 rows.
# Importing S-data into: C:\Users\axell\Desktop\CBS\data\OptionMetrics\OEX2\returns and stock price.csv
# Collecting data: 100%|██████████| 11/11 [00:07<00:00,  1.57years/s]
# Data collected and saved: 386872 rows.
# Importing Z-data into: C:\Users\axell\Desktop\CBS\data\OptionMetrics\OEX2\ZC yield curve.csv
# Data collected and saved: 27893 rows.

# %%
wp.

# %%
importlib.reload(wl)

wl.fetch_wrds_data( 
    db = db,
    folder_name="VIX",
    begdate="1996-01-01", 
    enddate="2024-12-31", #2024-12-31 2003-02-28
    save_per="Y", #None "Y" "M"
    tickers = ["SPX", "GOOGL", "AMZN", "DIA", "IWM", "QQQ", "AAPL", "EWZ", "USO", "GS", "EEM", "FXE", "SLV", "IBM", "TLT"],
    progress=True,
    chunk_size=4000000,
    return_df=False
)
# Out:
# Importing O-data split per 'Y' into folder: C:\Users\axell\Desktop\CBS\data\OptionMetrics\VIX
# Collecting data: 100%|██████████| 28/28 [19:37<00:00, 42.04s/years]
# Importing F-data into: C:\Users\axell\Desktop\CBS\data\OptionMetrics\VIX\forward price.csv
# Collecting data: 100%|██████████| 28/28 [00:17<00:00,  1.58years/s]
# Data collected and saved: 993934 rows.
# Importing S-data into: C:\Users\axell\Desktop\CBS\data\OptionMetrics\VIX\returns and stock price.csv
# Collecting data: 100%|██████████| 28/28 [00:09<00:00,  2.91years/s]
# Data collected and saved: 99566 rows.
# Importing Z-data into: C:\Users\axell\Desktop\CBS\data\OptionMetrics\VIX\ZC yield curve.csv
# Data collected and saved: 72597 rows.

# %%
importlib.reload(wl)

wl.fetch_wrds_data(
    db = db, 
    folder_name="OEX",
    begdate="1996-01-01", 
    enddate="2024-12-31", #2024-12-31 2003-02-28
    save_per="Y", #None "Y" "M"
    tickers = ["OEX", "OEF","AA", "AAPL", "ABBV", "ABT", "ACN", "ADBE", 
               "AEP", "AES", "AGN", "AIG", "ALL", "AMD", "AMGN", "AMT", 
               "AMZN", "APA", "APC", "ATI", "AVGO", "AVP", "AXP", "BA", 
               "BAC", "BAX", "BDK", "BHI", "BIIB", "BK", "BKNG", "BMY", 
               "BNI", "BRK", "BUD", "C", "CAT", "CELG", "CGP", "CHTR", "CI", 
               "CL", "CLB", "CMCSA", "CMCSK", "COF", "COP", "COST", "COV", 
               "CPB", "CRM", "CSC", "CSCO", "CVS", "CVX", "DAL", "DD", "DE", 
               "DELL", "DHR", "DIS", "DOW", "DUK", "DVN", "EBAY", "EMC", "EMR", 
               "ENE", "EP", "ETR", "EXC", "F", "FCX", "FDX", "G", "GBLX", "GD", 
               "GE", "GILD", "GM", "GOOG", "GOOGL", "GS", "GTX", "HAL", "HCA", 
               "HD", "HET", "HIG", "HNZ", "HON", "HPQ", "HSH", "IBM", "INTC", 
               "IP", "JCI", "JNJ", "JPM", "KHC", "KMI", "KO", "LEH", "LIN", 
               "LLY", "LMT", "LOW", "MA", "MAY", "MCD", "MDLZ", "MDT", "MER", 
               "MET", "META", "MMM", "MO", "MON", "MRK", "MS", "MSFT", "NEE", 
               "NFLX", "NKE", "NOV", "NSC", "NSM", "NT", "NVDA", "NXTL", "NYX", 
               "OMX", "ONE", "ORCL", "OXY", "PARA", "PEP", "PFE", "PG", "PM", 
               "PNU", "PYPL", "QCOM", "RAL", "RF", "ROK", "RSH", "RTN", "RTX", 
               "S", "SBUX", "SCHW", "SGP", "SLB", "SO", "SPG", "T", "TGT", "TMO", 
               "TMUS", "TOY", "TSLA", "TWX", "TXN", "UBAN", "UIS", "UNH", "UNP", 
               "UPS", "USB", "V", "VZ", "WB", "WBA", "WFC", "WMB", "WMT", "WY", 
               "WYE", "XOM", "XRX"],
    progress=True,
    chunk_size=4000000,
    return_df=False
) 


wl.fetch_wrds_data(
    db = db,
    folder_name="Liquid_ETFs",
    begdate="1996-01-01", 
    enddate="2024-12-31", #2024-12-31 2003-02-28
    save_per="Y", #None "Y" "M"
    tickers = ["SPX", "OEX", "DJX", "NDX", "SPY", "OEF", "DIA", "QQQ"],
    progress=True,
    chunk_size=4000000,
    return_df=False
) 


wl.fetch_wrds_data(
    db = db,
    folder_name="Cross_AM",
    begdate="1996-01-01", 
    enddate="2024-12-31", #2024-12-31 2003-02-28
    save_per="Y", #None "Y" "M"
    tickers = ["SPX", "VGK", "FXI", "EWJ", "EWZ", "INDA", "EZA", "EWC", 
               "EWU", "EWY", "EWA", "EWW", "VNQ", "TLT", "SHY", "TIP", 
               "LQD", "HYG", "EMB", "IAU", "SLV", "UNG", "USO", "UVXY", 
               "UUP", "FXE", "FXY", "CEW", "BITO" ],
    progress=True,
    chunk_size=4000000,
    return_df=False
) 



wl.fetch_wrds_data(
    db = db,
    folder_name="VIX",
    begdate="1996-01-01", 
    enddate="2024-12-31", #2024-12-31 2003-02-28
    save_per="Y", #None "Y" "M"
    tickers = ["SPX", "GOOGL", "AMZN", "DIA", "IWM", "QQQ", "AAPL", "EWZ", "USO", "GS", "EEM", "FXE", "SLV", "IBM", "TLT"],
    progress=True,
    chunk_size=4000000,
    return_df=False
)
# Out:
# Importing O-data split per 'Y' into folder: C:\Users\axell\Desktop\CBS\data\OptionMetrics\OEX
# Collecting data:  29%|██▊       | 8/28 [07:32<18:50, 56.51s/years]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 3
#       1 importlib.reload(wl)
# ----> 3 wl.fetch_wrds_data(
#       4     db = db,
#       5     folder_name="OEX",
#       6     begdate="1996-01-01",
#       7     enddate="2024-12-31", #2024-12-31 2003-02-28
#       8     save_per="Y", #None "Y" "M"
#       9     tickers = ["OEX", "OEF","AA", "AAPL", "ABBV", "ABT", "ACN", "ADBE",
#      10                "AEP", "AES", "AGN", "AIG", "ALL", "AMD", "AMGN", "AMT",
#      11                "AMZN", "APA", "APC", "ATI", "AVGO", "AVP", "AXP", "BA",
#      12                "BAC", "BAX", "BDK", "BHI", "BIIB", "BK", "BKNG", "BMY",
#      13                "BNI", "BRK", "BUD", "C", "CAT", "CELG", "CGP", "CHTR", "CI",
#      14                "CL", "CLB", "CMCSA", "CMCSK", "COF", "COP", "COST", "COV",
#      15                "CPB", "CRM", "CSC", "CSCO", "CVS", "CVX", "DAL", "DD", "DE",
#      16                "DELL", "DHR", "DIS", "DOW", "DUK", "DVN", "EBAY", "EMC", "EMR",
#      17                "ENE", "EP", "ETR", "EXC", "F", "FCX", "FDX", "G", "GBLX", "GD",
#      18                "GE", "GILD", "GM", "GOOG", "GOOGL", "GS", "GTX", "HAL", "HCA",
#      19                "HD", "HET", "HIG", "HNZ", "HON", "HPQ", "HSH", "IBM", "INTC",
#      20                "IP", "JCI", "JNJ", "JPM", "KHC", "KMI", "KO", "LEH", "LIN",
#      21                "LLY", "LMT", "LOW", "MA", "MAY", "MCD", "MDLZ", "MDT", "MER",
#      22                "MET", "META", "MMM", "MO", "MON", "MRK", "MS", "MSFT", "NEE",
#      23                "NFLX", "NKE", "NOV", "NSC", "NSM", "NT", "NVDA", "NXTL", "NYX",
#      24                "OMX", "ONE", "ORCL", "OXY", "PARA", "PEP", "PFE", "PG", "PM",
#      25                "PNU", "PYPL", "QCOM", "RAL", "RF", "ROK", "RSH", "RTN", "RTX",
#      26                "S", "SBUX", "SCHW", "SGP", "SLB", "SO", "SPG", "T", "TGT", "TMO",
#      27                "TMUS", "TOY", "TSLA", "TWX", "TXN", "UBAN", "UIS", "UNH", "UNP",
#      28                "UPS", "USB", "V", "VZ", "WB", "WBA", "WFC", "WMB", "WMT", "WY",
#      29                "WYE", "XOM", "XRX"],
#      30     progress=True,
#      31     chunk_size=4000000,
#      32     return_df=False
#      33 )
#      36 wl.fetch_wrds_data(
#      37     db = db,
#      38     folder_name="Liquid_ETFs",
#    (...)
#      45     return_df=False
#      46 )
#      49 wl.fetch_wrds_data(
#      50     db = db,
#      51     folder_name="Cross_AM",
#    (...)
#      61     return_df=False
#      62 )
#
# File c:\Users\axell\Desktop\CBS\master\volpy\wrds_lib.py:1290, in fetch_wrds_data(db, folder_name, begdate, enddate, save_per, tickers, data_types, return_df, progress, chunk_size)
#    1288 if save_per in ("M", "Y"):
#    1289     print(f"Importing O-data split per '{save_per}' into folder: {base_dir}")
# -> 1290     df = fetch_options_data_multiplefiles(
#    1291         db=db,
#    1292         begdate=begdate,
#    1293         enddate=enddate,
#    1294         tickers=tickers,
#    1295         output_dir=base_dir / "option data",
#    1296         data_frq=save_per,
#    1297         return_df=return_df,
#    1298         chunk_size=chunk_size
#    1299     )
#    1300 else:
#    1301     csv_path = base_dir / "option data.csv"
#
# File c:\Users\axell\Desktop\CBS\master\volpy\wrds_lib.py:389, in fetch_options_data_multiplefiles(db, begdate, enddate, tickers, output_dir, data_frq, return_df, chunk_size)
#     345 while True:
#     346     # Hent data i chunks
#     347     # sql_chunk = f"""
#    (...)
#     371     #     LIMIT {chunk_size} OFFSET {offset}
#     372     # """
#     374     sql_chunk = f"""
#     375         SELECT o.secid, s.ticker, o.optionid,
#     376             o.date, o.exdate, o.cp_flag, o.strike_price,
#    (...)
#     386         LIMIT {chunk_size} OFFSET {offset}
#     387     """
# --> 389     chunk = db.raw_sql(sql_chunk, date_cols=["date", "exdate"])
#     391     if chunk.empty:
#     392         break  # ingen flere data i dette år
#
# File ~\AppData\Roaming\Python\Python311\site-packages\wrds\sql.py:590, in Connection.raw_sql(self, sql, coerce_float, date_cols, index_col, params, chunksize, return_iter, dtype, dtype_backend)
#     588 else:
#     589     full_df = pd.DataFrame()
# --> 590     for chunk in df:
#     591         full_df = pd.concat([full_df, chunk])
#     592     return full_df
#
# File c:\Users\axell\anaconda3\Lib\site-packages\pandas\io\sql.py:1769, in SQLDatabase._query_iterator(result, exit_stack, chunksize, columns, index_col, coerce_float, parse_dates, dtype, dtype_backend)
#    1766     break
#    1768 has_read_data = True
# -> 1769 yield _wrap_result(
#    1770     data,
#    1771     columns,
#    1772     index_col=index_col,
#    1773     coerce_float=coerce_float,
#    1774     parse_dates=parse_dates,
#    1775     dtype=dtype,
#    1776     dtype_backend=dtype_backend,
#    1777 )
#
# File c:\Users\axell\anaconda3\Lib\site-packages\pandas\io\sql.py:204, in _wrap_result(data, columns, index_col, coerce_float, parse_dates, dtype, dtype_backend)
#     194 def _wrap_result(
#     195     data,
#     196     columns,
#    (...)
#     201     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#     202 ):
#     203     """Wrap result set of a SQLAlchemy query in a DataFrame."""
# --> 204     frame = _convert_arrays_to_dataframe(data, columns, coerce_float, dtype_backend)
#     206     if dtype:
#     207         frame = frame.astype(dtype)
#
# File c:\Users\axell\anaconda3\Lib\site-packages\pandas\io\sql.py:167, in _convert_arrays_to_dataframe(data, columns, coerce_float, dtype_backend)
#     160 def _convert_arrays_to_dataframe(
#     161     data,
#     162     columns,
#     163     coerce_float: bool = True,
#     164     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#     165 ) -> DataFrame:
#     166     content = lib.to_object_array_tuples(data)
# --> 167     arrays = convert_object_array(
#     168         list(content.T),
#     169         dtype=None,
#     170         coerce_float=coerce_float,
#     171         dtype_backend=dtype_backend,
#     172     )
#     173     if dtype_backend == "pyarrow":
#     174         pa = import_optional_dependency("pyarrow")
#
# File c:\Users\axell\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:1070, in convert_object_array(content, dtype, dtype_backend, coerce_float)
#    1066             arr = maybe_cast_to_datetime(arr, dtype)
#    1068     return arr
# -> 1070 arrays = [convert(arr) for arr in content]
#    1072 return arrays
#
# File c:\Users\axell\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:1070, in <listcomp>(.0)
#    1066             arr = maybe_cast_to_datetime(arr, dtype)
#    1068     return arr
# -> 1070 arrays = [convert(arr) for arr in content]
#    1072 return arrays
#
# File c:\Users\axell\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:1043, in convert_object_array.<locals>.convert(arr)
#    1035 # Notes on cases that get here 2023-02-15
#    1036 # 1) we DO get here when arr is all Timestamps and dtype=None
#    1037 # 2) disabling this doesn't break the world, so this must be
#    1038 #    getting caught at a higher level
#    1039 # 3) passing convert_non_numeric to maybe_convert_objects get this right
#    1040 # 4) convert_non_numeric?
#    1042 if dtype is None:
# -> 1043     if arr.dtype == np.dtype("O"):
#    1044         # i.e. maybe_convert_objects didn't convert
#    1045         arr = maybe_infer_to_datetimelike(arr)
#    1046         if dtype_backend != "numpy" and arr.dtype == np.dtype("O"):
#
# KeyboardInterrupt:

# %%
#cerate data directly from api 
importlib.reload(wl)

# axel pseuodo opt chunk_size = 4000000

wl.fetch_wrds_data(
    db = db,
    folder_name="OEX_constituents_short5",
    begdate="1996-01-01", 
    enddate="2003-12-31", #2024-12-31 2003-02-28
    save_per="Y", #None "Y" "M"
    tickers = ["AA", "AEP", "AES", "AIG", "ALL", "AMGN", "ATI", "AVP", 
             "AXP", "BA", "BAC", "BAX", "BDK", "BHI", "BMY", "BNI", 
             "BUD", "C", "CGP", "CI", "CL", "CPB", "CSC", "CSCO", 
             "DAL", "DD", "DIS", "DOW", "EMC", "ENE", "EP", "ETR", 
             "EXC", "F", "FDX", "G", "GBLX", "GD", "GE", "GM", "GS", 
             "HAL", "HCA", "HD", "HET", "HIG", "HNZ", "HON", "HPQ", "HSH", 
             "IBM", "INTC", "IP", "JCI", "JNJ", "JPM", "KO", "LEH", "MAY", 
             "MCD", "MDT", "MER", "MMM", "MO", "MRK", "MS", "MSFT", "NSC", 
             "NSM", "NT", "NXTL", "OMX", "ONE", "ORCL", "PARA", "PEP", 
             "PFE", "PG", "PNU", "RAL", "ROK", "RSH", "RTN", "RTX", "S", 
             "SLB", "SO", "T", "TOY", "TWX", "TXN", "UBAN", "UIS", "USB", 
             "VZ", "WFC", "WMB", "WMT", "WY", "XOM", "XRX"],
    progress=True,
    chunk_size=4000000,
    return_df=False
) 

# HUSK AT ÆNDRE SETTINGS FOR ISSUER_TYPE !!!!!!


# [
#         "SPX", "VGK", "FXI", "EWJ", "EWZ", "INDA", "EZA", "EWC",
#         "EWU", "EWY", "EWA", "EWW", "VNQ",
#         "TLT", "SHY", "TIP", "LQD", "HYG", "EMB",
#         "IAU", "SLV", "UNG", "USO", "UVXY",
#         "UUP", "FXE", "FXY", "CEW", "BITO"],

# ["OEX", "AA", "AEP", "AES", "AIG", "ALL", "AMGN", "ATI", "AVP", 
#              "AXP", "BA", "BAC", "BAX", "BDK", "BHI", "BMY", "BNI", 
#              "BUD", "C", "CGP", "CI", "CL", "CPB", "CSC", "CSCO", 
#              "DAL", "DD", "DIS", "DOW", "EMC", "ENE", "EP", "ETR", 
#              "EXC", "F", "FDX", "G", "GBLX", "GD", "GE", "GM", "GS", 
#              "HAL", "HCA", "HD", "HET", "HIG", "HNZ", "HON", "HPQ", "HSH", 
#              "IBM", "INTC", "IP", "JCI", "JNJ", "JPM", "KO", "LEH", "MAY", 
#              "MCD", "MDT", "MER", "MMM", "MO", "MRK", "MS", "MSFT", "NSC", 
#              "NSM", "NT", "NXTL", "OMX", "ONE", "ORCL", "PARA", "PEP", 
#              "PFE", "PG", "PNU", "RAL", "ROK", "RSH", "RTN", "RTX", "S", 
#              "SLB", "SO", "T", "TOY", "TWX", "TXN", "UBAN", "UIS", "USB", 
#              "VZ", "WFC", "WMB", "WMT", "WY", "XOM", "XRX"],



# # ["OEX", "AIG", "AA", "AMGN", "AAPL", "T", "BA", "BAC", "BMY", "C", "CAT",
#             "CVX", "KO", "DD", "DE", "DOW", "XOM", "FDX", "F", "GD", "GE",
#             "GM", "HD", "HON", "HPQ", "IBM", "INTC", "JNJ", "JPM", "KMB", "LLY",
#             "LMT", "LOW", "MCD", "MDT", "MRK", "MSFT", "MMM", "MO", "NKE", "PFE",
#             "PG", "RTN", "SBUX", "TGT", "TXN", "UNH", "VZ", "WMT", "DIS", "XRX"], #["SPX","OEX","DJX","NDX","MSFT","IBM","GE","AMZN"]
# Out:
# Importing O-data split per 'Y' into folder: C:\Users\axell\Desktop\CBS\data\OptionMetrics\OEX_constituents_short5
# Collecting data: 100%|██████████| 8/8 [03:40<00:00, 27.58s/years]
# Importing F-data into: C:\Users\axell\Desktop\CBS\data\OptionMetrics\OEX_constituents_short5\forward price.csv
# Collecting data: 100%|██████████| 8/8 [00:12<00:00,  1.58s/years]
# Data collected and saved: 918503 rows.
# Importing S-data into: C:\Users\axell\Desktop\CBS\data\OptionMetrics\OEX_constituents_short5\returns and stock price.csv
# Data collected and saved: 188267 rows.
# Importing Z-data into: C:\Users\axell\Desktop\CBS\data\OptionMetrics\OEX_constituents_short5\ZC yield curve.csv
# Data collected and saved: 19285 rows.

# %% [markdown]
# # Create factor file

# %%
import importlib
import load_clean_lib
import pandas as pd

# %%
importlib.reload(load_clean_lib)
factor_df = load_clean_lib.download_factor_df()
factor_df.to_csv("data/factor_df.csv")
# Out:
# add other vol indexes

# %% [markdown]
# # Swap rate (sum_df and od_raw)

# %%
import importlib
import volpy_func_lib as vp
import load_clean_lib
import table_lib
import vol_strat_lib as vs
import option_returns as orpy
from global_settings import *

importlib.reload(vp)
importlib.reload(load_clean_lib)
importlib.reload(table_lib)
importlib.reload(vs)
importlib.reload(orpy)
# Out:
# <module 'option_returns' from 'c:\\Users\\axell\\Desktop\\CBS\\master\\volpy\\option_returns.py'>

# %%
ticker_list = None #["SPX", "OEX"]
IV_type = "om" # om = OptionMetrics IV, "bid"/"ask"/"mid" price
om_folder = "oex_only2" #i4s4_CW, SPX_short, SPX_full, i2s1_full_v2, vix_markets_full

sum_df1, od_df1 = vp.load_analyze_create_swap(
    om_folder=om_folder, 
    ticker_list=ticker_list, 
    first_day=None, 
    last_day=None, 
    IV_type=IV_type, 
    save_files = True,
    safe_slow_IV = False
)
# Out:
# t_ was selected in global_settings.py
# Data loaded
# Processing Groups: 100%|██████████| 24902/24902 [00:20<00:00, 1206.94it/s]

# %% [markdown]
# ### version with chunking

# %%
ticker_list = None #["SPX", "OEX"] 
IV_type = "om" # om = OptionMetrics IV, "bid"/"ask"/"mid" price 
om_folder = "OEX_constituents_short5" #i4s4_CW, SPX_short, SPX_full, i2s1_full_v2, vix_markets_full 

sum_df = vp.load_analyze_create_swap_chunks(
    om_folder=om_folder, 
    ticker_list=ticker_list, 
    first_day=None, 
    last_day=None, 
    IV_type=IV_type, 
    save_files = True,
    safe_slow_IV = False)
# Out:
# t_ was selected in global_settings.py
# Data loaded
# Processing Groups: 100%|██████████| 17522/17522 [00:13<00:00, 1265.36it/s]
# t_ was selected in global_settings.py
# Data loaded
# Processing Groups: 100%|██████████| 24856/24856 [00:20<00:00, 1186.83it/s]
# t_ was selected in global_settings.py
# Data loaded
# Processing Groups: 100%|██████████| 25812/25812 [00:22<00:00, 1130.41it/s]
# t_ was selected in global_settings.py
# Data loaded
# Processing Groups: 100%|██████████| 27062/27062 [00:23<00:00, 1147.13it/s]
# t_ was selected in global_settings.py
# Data loaded
# Processing Groups: 100%|██████████| 28748/28748 [00:24<00:00, 1163.80it/s]
# t_ was selected in global_settings.py
# Data loaded
# Processing Groups: 100%|██████████| 27582/27582 [00:22<00:00, 1234.10it/s]
# t_ was selected in global_settings.py
# Data loaded
# Processing Groups: 100%|██████████| 25970/25970 [00:21<00:00, 1183.74it/s]
# t_ was selected in global_settings.py
# Data loaded
# Processing Groups: 100%|██████████| 21782/21782 [00:18<00:00, 1190.96it/s]

# %% [markdown]
# # Option Strategies (sum_df_big and df_orpy) straddle, butterfly ect.

# %%
om_folder = "TESTTT6" #SPX_full, i2s1_full_v2, SPX_short
sum_df, od_raw = vs.import_sum_raw(om_folder = om_folder)

# %%
price_type = "mid"
IV_type = "om"
OTMs = [0.05, 0.15]

sum_df1, df_orpy1 = vs.create_option_sgys(
    sum_df, 
    od_raw, 
    price_type=price_type, 
    IV_type=IV_type, 
    OTMs=OTMs, 
    om_folder = om_folder,
    save_files=True
)

# %% [markdown]
# ### version with chunking

# %%
# sum_df = pd.read_csv(r"C:\Users\axell\Desktop\CBS\data\OptionMetrics\volpy data output\sp100_pseudo2\t_summary_dly.csv")
# sum_df["date"] = pd.to_datetime(sum_df["date"])
# sum_df[f"return_next"] = sum_df[f"return"].shift(-1)

# %%
price_type = "mid"
IV_type = "om"
OTMs = [0.05, 0.15]
om_folder = "OEX_constituents_short5"

sum_df2, df_orpy2 = vs.create_option_sgys_from_chunks(
    sum_df = sum_df, 
    price_type=price_type, 
    IV_type=IV_type, 
    OTMs=OTMs, 
    om_folder = om_folder,
    save_files_each_chunk=False,
    save_files=True #gemmer orpy som en stor
)
# Out:
# Processing option chunks: 100%|██████████| 8/8 [01:11<00:00,  8.90s/file]

# %%
df_orpy2['de']
# Out:
# 0             NaN
# 1       -0.078932
# 2       -0.235126
# 3        0.405728
# 4        0.218281
#            ...
# 92593         NaN
# 92594         NaN
# 92595         NaN
# 92596         NaN
# 92597         NaN
# Name: CF_30_straddle, Length: 92598, dtype: float64

# %%
sum_df2['close']
