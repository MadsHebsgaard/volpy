# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

import numpy as np
import pandas as pd
import importlib
import matplotlib.pyplot as plt
from pyarrow import table

import volpy_func_lib as vp
import volpy_func_ticker_lib as vtp
import load_clean_lib
import table_lib
import vol_strat_lib as vs
import option_returns as orpy
from volpy_func_lib import return_df, VIX_tickers

importlib.reload(vtp)
importlib.reload(vp)
importlib.reload(load_clean_lib)
importlib.reload(table_lib)
importlib.reload(vs)
# Out:
# <module 'vol_strat_lib' from 'D:\\Professionelt\\Code\\volpy\\vol_strat_lib.py'>

# %% [markdown]
# # Summary visualizations

# %%
orpy_df, sum_df = vs.import_orpy_sum(om_folder = "VIX")
df = sum_df[sum_df["ticker"]=="SPX"].copy().reset_index(drop=True)
df = df.set_index('date')
# Out:
# D:\Professionelt\Code\volpy\vol_strat_lib.py:33: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   orpy_df = pd.read_csv(f"{om_folder}/{time_type}df_orpy.csv")

# %%
importlib.reload(vp)
vp.plot_timeseries_with_pct(df, alpha = 0.1, var = "days", var_name = "TTM (trading days)", figsize = (9,4), savefig=True)

# %%
vp.plot_timeseries_with_pct(df, alpha = 0.1, var = "#K", var_name = "# Strikes", figsize = (6,4), savefig=True)

# %%
vp.plot_lowest_number_of_strikes_timeseries(df, figsize = (6,4), savefig=True)

# %% [markdown]
# # Summary tables

# %%
import numpy as np
import pandas as pd
import importlib
import matplotlib.pyplot as plt
from pyarrow import table

import volpy_func_lib as vp
import load_clean_lib
import table_lib
import vol_strat_lib as vs
import option_returns as orpy
from volpy_func_lib import return_df
import volpy_func_ticker_lib as vtp

importlib.reload(vtp)
importlib.reload(vp)
importlib.reload(load_clean_lib)
importlib.reload(table_lib)
importlib.reload(vs)

import os
os.makedirs("figures/summary", exist_ok=True)

# %% [markdown]
# # VIX

# %%
importlib.reload(vp)
om_folder = "VIX" #SPX_full, i2s1_full_v2', vix_markets_full, vix_full_dataset
orpy_df, sum_df = vs.import_orpy_sum(om_folder = om_folder)

importlib.reload(table_lib)
table_lib.table_dataset_list_strike_count(sum_df, name = om_folder)
# Out:
# D:\Professionelt\Code\volpy\vol_strat_lib.py:33: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   orpy_df = pd.read_csv(f"{om_folder}/{time_type}df_orpy.csv")
#    ticker Starting_date  Ending_date     N         NK    Q1_K   Q5_K  Q10_K
# 0     SPX   04-Jan-1996  31-Aug-2023  6963  91.356958  22.000  25.00   27.5
# 1   GOOGL   27-Aug-2004  31-Aug-2023  4786  66.197137  18.425  25.00   29.0
# 2    AMZN   20-Nov-1997  31-Aug-2023  6439  56.855645   4.000   5.50    7.0
# 3     DIA   20-May-2002  31-Aug-2023  5864  44.053973  13.500  16.00   18.0
# 4     IWM   18-Oct-2000  31-Aug-2023  5776  42.132704   3.500   5.50   11.5
# 5     QQQ   11-Mar-1999  31-Aug-2023  6159  41.306949   6.500   8.50   10.5
# 6    AAPL   04-Jan-1996  31-Aug-2023  6691  30.388283   3.500   4.50    5.5
# 7     EWZ   26-May-2006  31-Aug-2023  4331  26.808127   3.500   6.75   10.5
# 8     USO   09-May-2007  31-Aug-2023  4107  25.975164   6.500   8.00   10.0
# ...

# %% [markdown]
# # Cross-AM

# %%
importlib.reload(vp)
om_folder = "Cross-AM" #SPX_full, i2s1_full_v2', vix_markets_full, vix_full_dataset
orpy_df, sum_df = vs.import_orpy_sum(om_folder = om_folder)

importlib.reload(table_lib)
table_lib.table_dataset_list_strike_count(sum_df, name = om_folder)
# Out:
#    ticker Starting_date  Ending_date     N         NK   Q1_K   Q5_K  Q10_K
# 0     SPX   04-Jan-1996  31-Aug-2023  6963  91.356958  22.00  25.00   27.5
# 1    UVXY   19-Mar-2012  31-Aug-2023  2873  44.472329  11.00  16.80   20.5
# 2     TLT   28-Apr-2003  31-Aug-2023  5121  30.335579   6.00   7.50    9.0
# 3     EWZ   26-May-2006  31-Aug-2023  4331  26.808127   3.50   6.75   10.5
# 4     FXI   19-Oct-2004  31-Aug-2023  4670  26.257495   7.00  13.00   16.5
# 5     USO   09-May-2007  31-Aug-2023  4107  25.975164   6.50   8.00   10.0
# 6    BITO   20-Oct-2021  31-Aug-2023   467  25.477516   7.83  11.15   12.5
# 7     EWY   11-Jul-2007  31-Aug-2023  4157  23.971855  10.00  13.50   15.5
# 8     EWW   29-Nov-2007  31-Aug-2023  4057  22.850505   9.00  13.00   15.0
# 9     FXE   09-May-2007  31-Aug-2023  4098  21.112372   5.50   8.00    9.5
# 10    SLV   09-Dec-2008  31-Aug-2023  3700  19.644189   4.50   6.50    8.0
# ...
